# %% [markdown]
# # Type Casting

# %%
i = 10
float(i)
# Out:
# 10.0

# %%
str(i)
# Out:
# '10'

# %%
complex(i)
# Out:
# (10+0j)

# %%
bool(i)
# Out:
# True

# %%
f = 20.3
int(f)
# Out:
# 20

# %%
float(f)
# Out:
# 20.3

# %%
str(f)
# Out:
# '20.3'

# %%
complex(f)
# Out:
# (20.3+0j)

# %%
complex(8)
# Out:
# (8+0j)

# %%
complex(8,3)
# Out:
# (8+3j)

# %%
complex(False,True)
# Out:
# 1j

# %%
complex(8+2j)
# Out:
# (8+2j)

# %%
complex(8.3,4.5)
# Out:
# (8.3+4.5j)

# %%
complex(False, True)
# Out:
# 1j

# %%
complex('10')
# Out:
# (10+0j)

# %% [markdown]
# # Complex can't take 2 string parameters

# %%
complex('10',20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 complex('10',20)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(20,'10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 complex(20,'10')
#
# TypeError: complex() second arg can't be a string

# %%
print(str(1+2j))
# Out:
# (1+2j)
