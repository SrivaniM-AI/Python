# %% [markdown]
# # Tuple

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t = (10,20,30)
t
# Out:
# (10, 20, 30)

# %%
t.count(20)
# Out:
# 1

# %%
t.index(20)
# Out:
# 1

# %%
t1 = (1, 'Hello', True)
t1
# Out:
# (1, 'Hello', True)

# %%
len(t)
# Out:
# 3

# %%
t3 = t1 + t
t3
# Out:
# (1, 'Hello', True, 10, 20, 30)

# %%
t[1:]
# Out:
# (20, 30)
