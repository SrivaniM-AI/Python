# %% [markdown]
# # Python Data structure

# %% [markdown]
# ## list

# %%
l = [2, 3, 4, 5, 6]
l
# Out:
# [2, 3, 4, 5, 6]

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 5

# %%
l.append(2)

# %%
l
# Out:
# [2, 3, 4, 5, 6, 2]

# %%
len(l)
# Out:
# 6

# %%
l.clear()
l
# Out:
# []

# %%
l = [2, 3, 4, 5, 6]
l
# Out:
# [2, 3, 4, 5, 6]

# %%
m = l.copy()
m
# Out:
# [2, 3, 4, 5, 6]

# %%
l.count(2)
# Out:
# 1

# %%
l.extend(m)
l
# Out:
# [2, 3, 4, 5, 6, 2, 3, 4, 5, 6]

# %%
l.index(5)
# Out:
# 3

# %%
l.insert(3,10)
l
# Out:
# [2, 3, 4, 10, 5, 6, 2, 3, 4, 5, 6]

# %%
l.pop(3)
# Out:
# 10

# %%
l
# Out:
# [2, 3, 4, 5, 6, 2, 3, 4, 5, 6]

# %%
l.remove(3)

# %%
l
# Out:
# [2, 4, 5, 6, 2, 3, 4, 5, 6]

# %%
l.reverse()

# %%
l
# Out:
# [6, 5, 4, 3, 2, 6, 5, 4, 2]

# %%
l.sort()
l
# Out:
# [2, 2, 3, 4, 4, 5, 5, 6, 6]

# %%
l.append('hello')
l
# Out:
# [2, 2, 3, 4, 4, 5, 5, 6, 6, 'hello']

# %%
m
# Out:
# [2, 3, 4, 5, 6]

# %%
del m

# %%
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 m
#
# NameError: name 'm' is not defined

# %%
m = range(1,10)
m
# Out:
# range(1, 10)

# %%
print(m)
# Out:
# range(1, 10)

# %%
m = [2,5,3,8, 0]
m
# Out:
# [2, 5, 3, 8, 0]

# %%
l.append(m)

# %%
l
# Out:
# [2, 2, 3, 4, 4, 5, 5, 6, 6, 'hello', [2, 5, 3, 8, 0]]

# %%
l.extend(m)

# %%
l
# Out:
# [2, 2, 3, 4, 4, 5, 5, 6, 6, 'hello', [2, 5, 3, 8, 0], 2, 5, 3, 8, 0]

# %%
type(l)
# Out:
# list

# %%
for i in l:
    print(i)
# Out:
# 2
# 2
# 3
# 4
# 4
# 5
# 5
# 6
# 6
# hello
# [2, 5, 3, 8, 0]
# 2
# 5
# 3
# 8
# 0

# %% [markdown]
# # List Slicing

# %%
l
# Out:
# [2, 2, 3, 4, 4, 5, 5, 6, 6, 'hello', [2, 5, 3, 8, 0], 2, 5, 3, 8, 0]

# %%
l = [10,20,30,40]
l
# Out:
# [10, 20, 30, 40]

# %%
l[2]
# Out:
# 30

# %%
l[1:]
# Out:
# [20, 30, 40]

# %%
l[-1]
# Out:
# 40

# %%
l[:3]
# Out:
# [10, 20, 30]

# %%
l[:-1]
# Out:
# [10, 20, 30]

# %%
l[-1:-3]
# Out:
# []

# %%
l[-1:]
# Out:
# [40]

# %%
l[-1:3]
# Out:
# []

# %%
l[::-1]
# Out:
# [40, 30, 20, 10]

# %%
l[::2]
# Out:
# [10, 30]

# %%
l = [10,20,30,40,50,60,70,80,90,12,13,14,15]

# %%
l[::2]
# Out:
# [10, 30, 50, 70, 90, 13, 15]

# %%
l[::3]
# Out:
# [10, 40, 70, 12, 15]

# %%
l[1:10:3]
# Out:
# [20, 50, 80]

# %%
l[3:5:6]
# Out:
# [40]

# %%
l[1:10:3]
# Out:
# [20, 50, 80]

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, 40)
# (4, 50)
# (5, 60)
# (6, 70)
# (7, 80)
# (8, 90)
# (9, 12)
# (10, 13)
# (11, 14)
# (12, 15)

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [90, 80, 70, 60, 50, 40, 30, 20, 15, 14, 13, 12, 10]

# %%
l.sort()

# %%
l
# Out:
# [10, 12, 13, 14, 15, 20, 30, 40, 50, 60, 70, 80, 90]
