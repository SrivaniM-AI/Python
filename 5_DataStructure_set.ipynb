# %% [markdown]
# # Set

# %%
s = {}
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s = {10,32,20,45,34,90,32}

# %%
type(s)
# Out:
# set

# %%
s #Automatically sorted and removes duplicates
# Out:
# {10, 20, 32, 34, 45, 90}

# %%
s.add('Hello')
s
# Out:
# {10, 20, 32, 34, 45, 90, 'Hello'}

# %% [markdown]
# # A set can not contain mutable data types like list and dictionary. It can contain immutable data types like string, int, float, complex and tuple

# %%
s.add([1,2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s.add([1,2])  # A set can not contain mutable data types like list and dictionary. It can contain immutable data types like string, int, float, complex and tuple
#
# TypeError: unhashable type: 'list'

# %%
s.add(40)
s
# Out:
# {10, 20, 32, 34, 40, 45, 90}

# %%
s
# Out:
# {10, 20, 32, 34, 40, 45, 90, 'Hello'}

# %% [markdown]
# # id address of memory location

# %%
print(id(s))
# Out:
# 2503394237952

# %%
s1 = s.copy()
s1
# Out:
# {10, 20, 32, 34, 40, 45, 90}

# %% [markdown]
# # difference (-), difference_update(-=); difference_update and -= are same

# %%
s.add(12)
s.add(13)
s.add(14)
s.add(15)
print(s)
print(s1)
# Out:
# {10, 12, 13, 14, 15, 20, 90, 32, 34, 40, 45}
# {1, 2, 3, 4, 5}

# %%
diff = s.difference(s1)
print(diff)
print(s)
print(s1)
# Out:
# {32, 34, 40, 10, 12, 13, 14, 15, 45, 20, 90}
# {10, 12, 13, 14, 15, 20, 90, 32, 34, 40, 45}
# {1, 2, 3, 4, 5}

# %%
diff1 = s - s1
diff1
# Out:
# {12, 13, 14, 15}

# %%
s.difference_update(s1)
print(s)
print(s1)
# Out:
# {12, 13, 14, 15}
# {32, 34, 20, 90, 40, 10, 333, 45}

# %%
s.add(100)
s.add(200)
s.add(300)
s.add(10)
print(s)
print(s1)
print(diff)
# Out:
# {200, 10, 12, 13, 14, 15, 20, 90, 32, 34, 100, 40, 300, 45}
# {1, 2, 3, 4, 5}
# {32, 34, 40, 10, 12, 13, 14, 15, 45, 20, 90}

# %%
s-=s1
print(s)
print(s1)
print(diff)
# Out:
# {200, 12, 13, 14, 15, 100, 300}
# {32, 34, 20, 90, 40, 10, 333, 45}
# {12, 13, 14, 15}

# %% [markdown]
# # discard remove

# %%
s.discard(200)
s.remove(300)
s.pop()
# Out:
# 10

# %% [markdown]
# # Disjoint(No common), subset, superset

# %%
a = {1, 2, 3, 4, 5, 6, 7, 8}
b = {3,4,5}
c = {10,20 ,30}

# %%
a.issubset(b)
# Out:
# False

# %%
b.issubset(a)
# Out:
# True

# %%
a.issuperset(b)
# Out:
# True

# %%
b.issuperset(a)
# Out:
# False

# %%
c.isdisjoint(a)
# Out:
# True

# %%
s.

# %% [markdown]
# # intersection and intersection update

# %%
print(s)
print(s1)
# Out:
# {12, 13, 14, 15, 100}
# {32, 34, 20, 90, 40, 10, 333, 45}

# %%
s.add(100)
s.add(200)
s.add(300)
s.add(10)

# %%
print(s)
print(s1)
# Out:
# {200, 10, 12, 13, 14, 15, 100, 300}
# {32, 34, 20, 90, 40, 10, 333, 45}

# %%
intersect = s.intersection(s1)
intersect
# Out:
# {10}

# %%
inters = s & s1
inters
# Out:
# {10}

# %%
s.intersection_update(s1,intersect)
s
# Out:
# {10}

# %% [markdown]
# # Union (|)

# %%
union_set = s.union(s1,diff)
union_set
# Out:
# {10, 12, 13, 14, 15, 20, 32, 34, 40, 45, 90, 100, 200, 300, 333}

# %%
union_set1 = s | s1 | diff
union_set1
# Out:
# {10, 12, 13, 14, 15, 20, 32, 34, 40, 45, 90, 100, 200, 300, 333}

# %% [markdown]
# # Symmetric difference (^) & Symmetric difference update

# %%
s1 = {1,2,3,4,5}
s2 = {3,4,5,6,7}
s1.symmetric_difference(s2)
# Out:
# {1, 2, 6, 7}

# %% [markdown]
# # Update

# %%
s.update(s1,s2, diff)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 7, 10, 12, 13, 14, 15, 20, 32, 34, 40, 45, 90, 100}
