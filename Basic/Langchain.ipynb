# %%
pip install -U "langchain[openai]"
# Out:
# Requirement already satisfied: langchain[openai] in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain[openai]) (1.3.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain[openai]) (1.1.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain[openai]) (2.13.3)
# Requirement already satisfied: langchain-openai in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain[openai]) (1.2.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (0.7.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (26.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain[openai]) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain[openai]) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain[openai]) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain[openai]) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain[openai]) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[openai]) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[openai]) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (0.25.0)
# Requirement already satisfied: anyio in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[openai]) (4.13.0)
# Requirement already satisfied: certifi in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[openai]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[openai]) (1.0.9)
# Requirement already satisfied: idna in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[openai]) (3.13)
# Requirement already satisfied: h11>=0.16 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[openai]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (2.6.3)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-openai->langchain[openai]) (2.32.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-openai->langchain[openai]) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai]) (0.14.0)
# Requirement already satisfied: sniffio in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai]) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai->langchain[openai]) (2026.4.4)
# Requirement already satisfied: colorama in c:\users\srivani\appdata\roaming\python\python314\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai]) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -U "langchain[google-genai]"
# Out:
# Requirement already satisfied: langchain[google-genai] in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain[google-genai]) (1.3.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain[google-genai]) (1.1.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain[google-genai]) (2.13.3)
# Collecting langchain-google-genai (from langchain[google-genai])
#   Downloading langchain_google_genai-4.2.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (0.7.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (26.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (0.25.0)
# Requirement already satisfied: anyio in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (4.13.0)
# Requirement already satisfied: certifi in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (1.0.9)
# Requirement already satisfied: idna in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (3.13)
# Requirement already satisfied: h11>=0.16 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (2.6.3)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.65.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading google_genai-1.73.1-py3-none-any.whl.metadata (52 kB)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai])
#   Downloading google_auth-2.49.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting websockets<17.0,>=13.0.0 (from google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai])
#   Downloading websockets-16.0-cp314-cp314-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\srivani\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (1.3.1)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai])
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai])
#   Downloading cryptography-46.0.7-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai])
#   Downloading cffi-2.0.0-cp314-cp314-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai])
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai])
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading langchain_google_genai-4.2.2-py3-none-any.whl (67 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-1.73.1-py3-none-any.whl (783 kB)
#    ---------------------------------------- 0.0/783.6 kB ? eta -:--:--
#    ---------------------------------------- 783.6/783.6 kB 5.1 MB/s  0:00:00
# Downloading google_auth-2.49.2-py3-none-any.whl (240 kB)
# Downloading websockets-16.0-cp314-cp314-win_amd64.whl (178 kB)
# Downloading cryptography-46.0.7-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.5 MB 4.1 MB/s eta 0:00:01
#    ------------ --------------------------- 1.0/3.5 MB 4.6 MB/s eta 0:00:01
#    --------------- ------------------------ 1.3/3.5 MB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.6/3.5 MB 1.9 MB/s eta 0:00:01
#    ------------------ --------------------- 1.6/3.5 MB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.8/3.5 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 2.4/3.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------ --------- 2.6/3.5 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.9/3.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 1.5 MB/s  0:00:02
# Downloading cffi-2.0.0-cp314-cp314-win_amd64.whl (185 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: filetype, websockets, pycparser, pyasn1, pyasn1-modules, cffi, cryptography, google-auth, google-genai, langchain-google-genai
#
#    ---- -----------------------------------  1/10 [websockets]
#    ---- -----------------------------------  1/10 [websockets]
#    -------- -------------------------------  2/10 [pycparser]
#    ------------ ---------------------------  3/10 [pyasn1]
#    ---------------- -----------------------  4/10 [pyasn1-modules]
#    ---------------- -----------------------  4/10 [pyasn1-modules]
#    ---------------- -----------------------  4/10 [pyasn1-modules]
#    ---------------- -----------------------  4/10 [pyasn1-modules]
#    -------------------- -------------------  5/10 [cffi]
#    ------------------------ ---------------  6/10 [cryptography]
#    ------------------------ ---------------  6/10 [cryptography]
#    ------------------------ ---------------  6/10 [cryptography]
#    ---------------------------- -----------  7/10 [google-auth]
#    ---------------------------- -----------  7/10 [google-auth]
#    ---------------------------- -----------  7/10 [google-auth]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    -------------------------------- -------  8/10 [google-genai]
#    ---------------------------------------- 10/10 [langchain-google-genai]
#
# Successfully installed cffi-2.0.0 cryptography-46.0.7 filetype-1.2.0 google-auth-2.49.2 google-genai-1.73.1 langchain-google-genai-4.2.2 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 websockets-16.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script filetype.exe is installed in 'c:\Users\Srivani\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script websockets.exe is installed in 'c:\Users\Srivani\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "AIzaSyCMhV6YzlMNs7z5cjOwWcyMYYCpHVREM48"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("What about IT jobs between 2026 and 2030")

# %%
print(response)
# Out:
# content="The period between 2026 and 2030 is shaping up to be a dynamic and exciting time for IT professionals. Based on current trends and projections, here's what you can expect:\n\n**Key Trends and Drivers:**\n\n* **Continued Digital Transformation:** Organizations across all sectors will continue to invest heavily in digital technologies to improve efficiency, customer experience, and competitiveness. This will drive demand for skilled IT professionals.\n* **AI and Machine Learning Dominance:** Artificial intelligence and machine learning will move beyond niche applications and become integral to many business processes. This will create significant opportunities in AI development, data science, and AI ethics.\n* **Cloud Computing Maturity:** The cloud will be the de facto standard for infrastructure and application deployment. Demand will remain high for cloud architects, engineers, and security specialists.\n* **Cybersecurity Imperative:** As digital threats evolve and become more sophisticated, cybersecurity will be a top priority. This will fuel a constant need for skilled security professionals across various specializations.\n* **Data Explosion and Analytics:** The sheer volume of data generated will continue to grow, making data analytics, big data engineering, and business intelligence crucial for extracting insights and driving decisions.\n* **Automation and Orchestration:** Automation will be a key focus, from robotic process automation (RPA) to infrastructure as code. Professionals who can design, implement, and manage automated systems will be in demand.\n* **Emerging Technologies Maturation:** Technologies like the Internet of Things (IoT), blockchain, and extended reality (AR/VR) will continue to mature and find more widespread adoption, creating new job roles and opportunities.\n* **Remote and Hybrid Work Models:** The shift towards remote and hybrid work is likely to persist, influencing the types of IT roles that are in demand and requiring skills in managing distributed teams and secure remote access.\n* **Sustainability and Green IT:** As environmental concerns grow, there will be an increasing focus on sustainable IT practices, leading to roles related to energy-efficient data centers and responsible technology deployment.\n\n**In-Demand IT Job Roles (2026-2030):**\n\nBased on these trends, here are some of the IT job roles that are likely to be in high demand:\n\n**Core & Emerging Technology Roles:**\n\n* **AI/Machine Learning Engineers & Scientists:** Developing, deploying, and optimizing AI models.\n* **Data Scientists & Analysts:** Extracting insights from large datasets, building predictive models.\n* **Cloud Architects & Engineers (AWS, Azure, GCP):** Designing, implementing, and managing cloud infrastructure.\n* **Cybersecurity Analysts & Engineers:** Protecting systems and data from threats, incident response.\n* **DevOps Engineers:** Bridging the gap between development and operations, automating workflows.\n* **Full-Stack Developers (with AI/ML integration skills):** Building comprehensive applications, increasingly incorporating AI features.\n* **Software Engineers (specializing in specific AI/ML frameworks or cloud-native development):** Deep expertise in building advanced software.\n* **IoT Engineers & Developers:** Designing and implementing connected devices and systems.\n* **Blockchain Developers & Architects:** Building decentralized applications and solutions.\n* **AR/VR Developers & Designers:** Creating immersive experiences for various applications.\n* **Data Engineers:** Building and maintaining data pipelines and infrastructure.\n\n**Infrastructure & Operations Roles:**\n\n* **Network Engineers (with a focus on cloud networking and security):** Managing and securing network infrastructure.\n* **Systems Administrators (with cloud and automation expertise):** Managing and maintaining IT systems.\n* **Database Administrators (with cloud and NoSQL experience):** Managing and optimizin ...
